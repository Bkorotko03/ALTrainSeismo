# %%
# first quick look at the data from jill's test platform run

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
plt.rcParams['xtick.top'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.minor.visible'] = True
plt.rcParams['ytick.minor.visible'] = True
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'DejaVu Sans'
# plt.rcParams['figure.figsize'] = (3,2)
# plt.rcParams["figure.dpi"] = 300
import os

# %%
overDF = pd.read_csv('./output/stationTest.CSV')

noMagDF = pd.read_csv('./output/noMagTRES2.CSV')

# %%
noMagDF
# Out:
#                timecode    seconds        lat lat_dir        lon lon_dir  \
# 0     260407_233210_000  84730.000  4159.9731       N  8739.4512       W
# 1     260407_233210_430  84730.430  4159.9731       N  8739.4512       W
# 2     260407_233210_529  84730.531  4159.9731       N  8739.4512       W
# 3     260407_233210_629  84730.633  4159.9731       N  8739.4512       W
# 4     260407_233210_729  84730.727  4159.9731       N  8739.4512       W
# ...                 ...        ...        ...     ...        ...     ...
# 1372  260407_233427_400  84867.398  4159.9849       N  8739.4482       W
# 1373  260407_233427_500  84867.500  4159.9849       N  8739.4482       W
# 1374  260407_233427_600  84867.602  4159.9849       N  8739.4482       W
# 1375  260407_233427_700  84867.703  4159.9849       N  8739.4482       W
# 1376  260407_233427_800  84867.797  4159.9849       N  8739.4482       W
#
#       sensor
# 0         94
# 1         73
# 2         76
# 3         79
# 4         80
# ...      ...
# 1372     124
# 1373     106
# 1374      88
# 1375       0
# 1376      13
#
# [1377 rows x 7 columns]

# %%
overDF['sensor'] = pd.to_numeric(overDF['sensor'], errors='coerce')
overDF['sensor']

overDF['seconds'] = pd.to_numeric(overDF['seconds'], errors='coerce')

# %%
noMagSens = np.array(noMagDF['sensor'])
noMagVolt = noMagSens * 5 / 16383
noMagSecs = np.array(noMagDF['seconds'])

# %%
overSens = np.array(overDF['sensor'])

overSecs = np.array(overDF['seconds'])

# %%
overSens = overSens[3000:-3000]
overSecs = overSecs[3000:-3000]

# %%
overVolt = overSens * 5 / 16383

# %%
plt.plot(overSecs,overVolt)

# %%
plt.plot(noMagSecs,noMagVolt)

# %%
noMagF,noMagPSD = sp.signal.welch(noMagVolt,fs=100,nperseg=300)

# %%
plt.plot(noMagF,noMagPSD)

# %%
overF,overPSD = sp.signal.welch(overVolt,fs=100,nperseg=300)

# %%
plt.plot(overF,overPSD)
